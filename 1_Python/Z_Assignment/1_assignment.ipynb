# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hell0 world")
# Out:
# Hell0 world

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
user_input= input("Enter your name")
print(user_input)
# Out:
# aman

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num = int(input("Enter a number"))
if num > 0:
    print(f"Your entered number {num} is poitive number")
elif num <0:
    print("Enter number {num} negative number") 
else:
    print(f"your enter a zero {num}")
# Out:
# your enter a zero 0

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
num1 = eval(input("Enter a 1st number "))
num2  = eval(input("Enter a 2nd number "))
num3 = eval(input("Enter a 3rd number "))

if num1== num2==num3:
    print(f"all entered number are same { num1}")
elif num1 == num2 > num3:
    print(f"Enter 1st number and 2nd number {num1} is greater than 3rd number {num3}  ")
elif num1 == num3 > num2:
    print(f"Enter 1st number and 3rd number {num1} is greater than 2nd number {num2}  ")
elif num2 == num3 > num1:
    print(f"Enter 2nd number and 3rd number {num2} is greater than 1st number {num1}  ")
elif (num1 > num2) and (num1 > num3):
    print(f"Enter 1st number {num1} is greater than 2nd number {num2} and 3rd number {num3} ")
elif(num2> num3) and (num2 > num1):
    print(f"Enter 2nd number {num2} is greater than 1st number {num1} and 3rd number {num3} ")
else:
    print(f"Enter 3rd number {num3} is greater than 2nd number {num2} and 1st number {num1} ")
# Out:
# Enter 3rd number 8 is greater than 2nd number 2.3 and 1st number 2.2

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
def factorial(n):
    if n ==0:
        return 1
    else:
        return n* factorial(n-1)
    
num = int(input("Enter a number: "))
print(f"Factorial of {num} = {factorial(num)}")
# Out:
# Factorial of 5 = 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
age = 16
print(age +2)
print(type(age))

marks = 7.9
print(marks)
print(type(marks))


name = "aman"
print(name)
print(type(name))

is_like = True
print(is_like)
print(type(is_like))
# Out:
# 18
# <class 'int'>
# 7.9
# <class 'float'>
# aman
# <class 'str'>
# True
# <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here

age = 45

change_typ = float(age)
print(change_typ)
type(change_typ)
# Out:
# 45.0
# float

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here

num = eval(input("Enter a number in ' celsius : "))
print(f"{num}'c into farhenheith = {num *1.8 +32}")
# Out:
# 5'c into farhenheith = 41.0

# %%
def fahrenheit(n):
    return num * 1.8 +32

num = eval(input("Enter a number in ' celsius : "))
print(f"{num}'c into farhenheith = {fahrenheit(num)}")
print(type(num))
# Out:
# 5'c into farhenheith = 41.0
# <class 'int'>

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here

a = "aman"
b= " kumar"
print(a + b)


c = "aniket\n"
d = "ray"

print(c+d)
# Out:
# aman kumar
# aniket
# ray

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here

var = eval(input("Enter a number: "))
if isinstance(var, type(var)):
    print(f"yes {var} is {type(var)}value")
else:
    print(f"No {var} is not {type(var)} value")
# Out:
# yes 5 is <class 'int'>value

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
num1 = eval(input("Enter a 1st number: "))
num2 = eval(input("Enter a 2nd number: "))

operation = int(input("Enter 1 for Addition \n2 for substraction \n3 for Multiplication \n4 for Division :"))
if operation == 1:
    print(f"Addition of {num1} + {num2} = {num1 + num2}" )
elif operation == 2:
    print(f"Subraction of {num1} - {num2} = {num1 - num2}" )
elif operation == 3:
    print(f" Multiplication of {num1} * {num2} = {num1 * num2}" )   
else:
    print(f" division of {num1} / {num2} = {num1 / num2}" )
# Out:
#  division of 25 / 25 = 1.0

# %%
# Solution
a = 5
b = 3

print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here

a = 45
b = 56

print(f"{a} == {b}: {a ==b} ")
print(f"{a} < {b} : {a < b}")
print(f"{a} > {b} : {a > b}")
print(f"{a} != {b} : {a !=b}")
# Out:
# 45 == 56: False
# 45 < 56 : True
# 45 > 56 : False
# 45 != 56 : True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here

a = True
b = False

print(f"true and false: {a and b}")
print(f"true and false: {a or b}")
print(f"not true:{not a}")
print(f"not true:{not b}")
# Out:
# true and false: False
# true and false: True
# not true:False
# not true:True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
def squar_num(n):
    return n * n

num = eval(input("Enter a number: "))
print(f" square of {num} is : {squar_num(num)}")
# Out:
#  square of 2 is: 4

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
n = int(input("Enter a number :"))
if n < 0:
    print(f"{n} is an integer number")
elif n%2 ==0:
    print(f"{n} is an even number")
else:
    print(f"{n} is an odd number")
# Out:
# 52 is an even number

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here

num = int(input("Enter a number :"))
sum = (num * (num+1))/2
print(sum)
# Out:
# 10.0

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here

year = int(input("Enter a year: 0"))
if (year % 4== 0 and year% 100!= 0) or (year %400 == 0):
    print(f"yeah {year} is a leap year")
else:
    print(f"No {year} is a not a leap year")
# Out:
# yeah 2024 is a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here

word = input("Enter a word")
rev_str = word[::-1]
print(f"reverse of { word} is {rev_str}")
# Out:
# reverse of aman is nama

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here

string = input("Enter a string:")

if string == string[::-1]:
    print(f"{string} is a palindrome")
else:
    print(f"{string} is not palindrome")
# Out:
# naman is a palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
