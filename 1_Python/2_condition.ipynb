# %% [markdown]
# 1. Introduction to condition statement.
# 2. if statement.
# 3. Else statement.
# 4. Elif statement.
# 5. Nested Conditional statements.
# 6. Practice problem.
# 7. common Errors and Best Practice.

# %%
## if statement
age = 20 
if age>= 18:
    print("you are allowed to vote in the election: ")
# Out:
# you are allowed to vote in the election:

# %%
age >= 16
# Out:
# True

# %% [markdown]
# Else --
# else work when if conditoion is false

# %%
age = 16
if age >= 18:
    print("you are eligible for voting")
else:
    print("you are minor")
# Out:
# you are minor

# %%
## ELIF -
# elif is work when multiple condition is given.

age = 17 
if age < 13:
    print("you are a child")
elif age <18:
    print("You are a teenager")
else:
    print("you are an adult")
# Out:
# You are a teenager

# %%
## NESTED COnditon Statement:
# You can place or more if, elif, or else stateents inside another if , elif,else statement to create Nested condition statement.



## Number is even , odd or negative.

num =  int(input("Enter a number : "))
if num>=0:
    print("The number is positive")
    if num%2 ==0:
        print("The number is even:")
    else:
        print("The number is odd:")
else:
    print("The number is Negative:")
# Out:
# Enter a number 5
# The number is positive
# The number is odd:

# %%
## PRACTICAL Example;
# Determine if a year is a leap year using nested conditin statement.

year = int(input("Enter a year"))
if year % 4==0:
    if year%100==0:
        if year%400==0:
            print(year, " is a leap year")
        else:
            print(year, " is  NOT a leap year")
    else:
        print(year, " is  a leap year")
else:
    print(year, " is  NOT a leap year")
# Out:
# Enter a year 2004
# 2004  is  a leap year

# %%
## ASSIGNMENT:
#1. simple calculator program
